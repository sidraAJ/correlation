# %%
import seaborn as sns

# Load the mtcars dataset from seaborn
mtcars = sns.load_dataset("mpg")

# Display the first few rows of the dataset
print(mtcars.head())

# Descriptive statistics using Pandas
summary_stats = mtcars.describe()
print("\nDescriptive Statistics:")
print(summary_stats)


# Visualization using Matplotlib and Seaborn
plt.figure(figsize=(15, 8))

# Scatter plot of horsepower vs. miles per gallon (mpg)
plt.figure(figsize=(8, 6))
sns.scatterplot(x='horsepower', y='mpg', data=mtcars)
plt.title('Horsepower vs. MPG')
plt.show()

# Boxplot of miles per gallon (mpg)
plt.subplot(2, 2, 2)
sns.boxplot(x=mtcars['mpg'])
plt.title('Boxplot of MPG')

# Histogram of number of cylinders
plt.figure(figsize=(8, 6))
sns.histplot(mtcars['cylinders'], bins=range(4, 9), kde=False)
plt.title('Distribution of Cylinders')
plt.show()

# Correlation heatmap
plt.subplot(2, 2, 4)
correlation_matrix = mtcars.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')

plt.tight_layout()
plt.show()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino
#
# Descriptive Statistics:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# ...
